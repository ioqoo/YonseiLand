# %%
import pandas as pd
import numpy as np
table_name_list = ['Class_Info', 'Mileage_Result']

# %%
df = pd.read_csv("YCA1007-05-00_2019_1.txt", names = range(20), sep = '\t')
groups = df[0].isin(table_name_list).cumsum()
tables = {g.iloc[0, 0] : g.iloc[1:] for k, g in df.groupby(groups)}

Class_Info = tables['Class_Info']
Class_Info = Class_Info.rename(columns=Class_Info.iloc[0])
Class_Info = Class_Info.drop(Class_Info.index[0])
Class_Info.reset_index(drop = True, inplace = True)
Class_Info.index += 1
Class_Info.dropna(axis = 1, how = 'all', inplace = True)

Mileage_Result = tables['Mileage_Result']
Mileage_Result = Mileage_Result.rename(columns=Mileage_Result.iloc[0])
Mileage_Result = Mileage_Result.drop(Mileage_Result.index[0])
Mileage_Result.reset_index(drop = True, inplace = True)
Mileage_Result.index += 1
Mileage_Result.dropna(axis = 1, how = 'all', inplace = True)

# %%
display(Class_Info)
display(Mileage_Result)
# Out:
#             학정번호    과목명  학점 담당교수 강의시간      강의실   정원  참여인원    전공자정원 1학년정원  \
# 1  YCA1007-05-00  채플(C)  .5  정미현   수5  대강당(신촌)  770  1242  600 (N)    10
#
#   2학년정원 3학년정원 4학년정원 교환가능여부 최대마일리지 최소값 최대값   평균값
# 1   520   120   120      O     36   1  36  4.02
#      순위 마일리지  전공자여부 신청과목수 졸업신청 초수강여부 총이수/졸업이수 직전학기이수/학기당수강 학년 수강여부  비고
# 1     1   36  N (N)     6    N     Y   0.4156       0.8947  3    O
# 2     2   36  N (N)     6    N     Y   0.2785       1.0000  2    O
# 3     3   36  N (N)     6    N     Y   0.2642       0.9210  2    O
# 4     4   36  N (N)     6    N     Y   0.2571       0.8684  2    O
# 5     5   36  N (N)     6    N     Y   0.2464       0.8947  2    O
# ...  ..  ...    ...   ...  ...   ...      ...          ... ..  ...  ..
# 1238  0    2  N (N)     5    N     Y   0.5814       0.7105  3    O  *
# 1239  0    2  N (N)     6    N     Y   0.5444       0.9473  3    O  *
# 1240  0    2  N (N)     4    N     Y   0.0000       0.8750  3    O  *
# ...

# %%
mask = (Mileage_Result['학년'] == '3')

# %%
display(Mileage_Result[mask])
# Out:
#       순위 마일리지  전공자여부 신청과목수 졸업신청 초수강여부 총이수/졸업이수 직전학기이수/학기당수강 학년 수강여부  비고
# 1      1   36  N (N)     6    N     Y   0.4156       0.8947  3    O
# 7      7   36  N (N)     0    N     Y   0.5464       1.0000  3    O
# 9      9   34  N (N)     6    N     Y   0.3357       0.6315  3    O
# 23    23   25  N (N)     6    N     Y   0.4960       0.8888  3    O
# 28    28   20  N (N)     6    N     Y   0.5000       0.9210  3    O
# ...   ..  ...    ...   ...  ...   ...      ...          ... ..  ...  ..
# 1238   0    2  N (N)     5    N     Y   0.5814       0.7105  3    O  *
# 1239   0    2  N (N)     6    N     Y   0.5444       0.9473  3    O  *
# 1240   0    2  N (N)     4    N     Y   0.0000       0.8750  3    O  *
# 1241   0    2  N (N)     6    N     Y   0.3814       0.7894  3    O  *
# 1242   0    2  N (N)     3    N     Y   0.4365       0.5000  3    O  *
#
# [268 rows x 11 columns]

# %%
pd.set_option('display.max_colwidth', None)

# %%
pd.set_option('display.max_rows', None)

# %%
display(Mileage_Result[mask])
# Out:
#         순위 마일리지  전공자여부 신청과목수 졸업신청 초수강여부 총이수/졸업이수 직전학기이수/학기당수강 학년 수강여부  비고
# 1        1   36  N (N)     6    N     Y   0.4156       0.8947  3    O
# 7        7   36  N (N)     0    N     Y   0.5464       1.0000  3    O
# 9        9   34  N (N)     6    N     Y   0.3357       0.6315  3    O
# 23      23   25  N (N)     6    N     Y   0.4960       0.8888  3    O
# 28      28   20  N (N)     6    N     Y   0.5000       0.9210  3    O
# 29      29   20  N (N)     6    N     Y   0.4761       0.7777  3    O
# 38      38   17  N (N)     6    N     Y   0.5535       1.0000  3    O
# 39      39   17  N (N)     6    N     Y   0.4785       0.8947  3    O
# 41      41   16  N (N)     6    N     Y   0.5000       0.9210  3    O
# 42      42   16  N (N)     5    N     Y   0.5000       0.8881  3    O
# 43      43   16  N (N)     4    N     Y   0.6107       0.7894  3    O
# 44      44   15  N (N)     6    N     Y   0.5000       0.9210  3    O
# ...

# %%
mask = (Mileage_Result['전공자여부'] == 'N (N)')

# %%
Mileage_Result.loc[mask, '전공자여부'] = 0

# %%
display(Mileage_Result)
# Out:
#         순위 마일리지  전공자여부 신청과목수 졸업신청 초수강여부 총이수/졸업이수 직전학기이수/학기당수강 학년 수강여부  비고
# 1        1   36      0     6    N     Y   0.4156       0.8947  3    O
# 2        2   36      0     6    N     Y   0.2785       1.0000  2    O
# 3        3   36      0     6    N     Y   0.2642       0.9210  2    O
# 4        4   36      0     6    N     Y   0.2571       0.8684  2    O
# 5        5   36      0     6    N     Y   0.2464       0.8947  2    O
# 6        6   36      0     6    N     Y   0.1642       0.3684  2    O
# 7        7   36      0     0    N     Y   0.5464       1.0000  3    O
# 8        8   35      0     6    N     Y   0.2071       0.9473  2    O
# 9        9   34      0     6    N     Y   0.3357       0.6315  3    O
# 10      10   34      0     6    N     Y   0.2928       1.0000  2    O
# 11      11   34      0     6    N     Y   0.2607       1.0000  2    O
# 12      12   34      0     6    N     Y   0.2607       0.8947  2    O
# ...

# %%
mask = ( (Mileage_Result['전공자여부'] == 'Y (N)') | (Mileage_Result['전공자여부'] == 'Y (Y)') )

# %%
Mileage_Result.loc[mask, '전공자여부'] = 1

# %%
display(Mileage_Result)
# Out:
#         순위 마일리지 전공자여부 신청과목수 졸업신청 초수강여부 총이수/졸업이수 직전학기이수/학기당수강 학년 수강여부  비고
# 1        1   36     0     6    N     Y   0.4156       0.8947  3    O
# 2        2   36     0     6    N     Y   0.2785       1.0000  2    O
# 3        3   36     0     6    N     Y   0.2642       0.9210  2    O
# 4        4   36     0     6    N     Y   0.2571       0.8684  2    O
# 5        5   36     0     6    N     Y   0.2464       0.8947  2    O
# 6        6   36     0     6    N     Y   0.1642       0.3684  2    O
# 7        7   36     0     0    N     Y   0.5464       1.0000  3    O
# 8        8   35     0     6    N     Y   0.2071       0.9473  2    O
# 9        9   34     0     6    N     Y   0.3357       0.6315  3    O
# 10      10   34     0     6    N     Y   0.2928       1.0000  2    O
# 11      11   34     0     6    N     Y   0.2607       1.0000  2    O
# 12      12   34     0     6    N     Y   0.2607       0.8947  2    O
# 13      13   34     0     6    N     Y   0.2428       0.9736  2    O
# ...

# %%
Mileage_Result = Mileage_Result.drop(['졸업신청', '초수강여부'], axis=1)

# %%
display(Mileage_Result)
# Out:
#         순위 마일리지 전공자여부 신청과목수 총이수/졸업이수 직전학기이수/학기당수강 학년 수강여부  비고
# 1        1   36     0     6   0.4156       0.8947  3    O
# 2        2   36     0     6   0.2785       1.0000  2    O
# 3        3   36     0     6   0.2642       0.9210  2    O
# 4        4   36     0     6   0.2571       0.8684  2    O
# 5        5   36     0     6   0.2464       0.8947  2    O
# 6        6   36     0     6   0.1642       0.3684  2    O
# 7        7   36     0     0   0.5464       1.0000  3    O
# 8        8   35     0     6   0.2071       0.9473  2    O
# 9        9   34     0     6   0.3357       0.6315  3    O
# 10      10   34     0     6   0.2928       1.0000  2    O
# 11      11   34     0     6   0.2607       1.0000  2    O
# 12      12   34     0     6   0.2607       0.8947  2    O
# 13      13   34     0     6   0.2428       0.9736  2    O
# 14      14   34     0     6   0.2428       0.7894  2    O
# 15      15   33     0     6   0.2785       1.0000  2    O
# ...

# %%
index = Mileage_Result[Mileage_Result['순위'] == '0'].index

# %%
Mileage_Result.drop(index, inplace = True)

# %%
display(Mileage_Result)
# Out:
#         순위 마일리지 전공자여부 신청과목수 총이수/졸업이수 직전학기이수/학기당수강 학년 수강여부 비고
# 1        1   36     0     6   0.4156       0.8947  3    O
# 2        2   36     0     6   0.2785       1.0000  2    O
# 3        3   36     0     6   0.2642       0.9210  2    O
# 4        4   36     0     6   0.2571       0.8684  2    O
# 5        5   36     0     6   0.2464       0.8947  2    O
# 6        6   36     0     6   0.1642       0.3684  2    O
# 7        7   36     0     0   0.5464       1.0000  3    O
# 8        8   35     0     6   0.2071       0.9473  2    O
# 9        9   34     0     6   0.3357       0.6315  3    O
# 10      10   34     0     6   0.2928       1.0000  2    O
# 11      11   34     0     6   0.2607       1.0000  2    O
# 12      12   34     0     6   0.2607       0.8947  2    O
# 13      13   34     0     6   0.2428       0.9736  2    O
# 14      14   34     0     6   0.2428       0.7894  2    O
# 15      15   33     0     6   0.2785       1.0000  2    O
# ...

# %%
Mileage_Result.drop('비고', axis=1, inplace = True)

# %%
mask = (Mileage_Result['수강여부'] == 'O')

# %%
mask2 = (Mileage_Result['수강여부'] == 'X')

# %%
Mileage_Result.loc[mask, '수강여부'] = 1

# %%
Mileage_Result.loc[mask2, '수강여부'] = 0

# %%
display(Mileage_Result)
# Out:
#         순위 마일리지 전공자여부 신청과목수 총이수/졸업이수 직전학기이수/학기당수강 학년 수강여부
# 1        1   36     0     6   0.4156       0.8947  3    1
# 2        2   36     0     6   0.2785       1.0000  2    1
# 3        3   36     0     6   0.2642       0.9210  2    1
# 4        4   36     0     6   0.2571       0.8684  2    1
# 5        5   36     0     6   0.2464       0.8947  2    1
# 6        6   36     0     6   0.1642       0.3684  2    1
# 7        7   36     0     0   0.5464       1.0000  3    1
# 8        8   35     0     6   0.2071       0.9473  2    1
# 9        9   34     0     6   0.3357       0.6315  3    1
# 10      10   34     0     6   0.2928       1.0000  2    1
# 11      11   34     0     6   0.2607       1.0000  2    1
# 12      12   34     0     6   0.2607       0.8947  2    1
# 13      13   34     0     6   0.2428       0.9736  2    1
# 14      14   34     0     6   0.2428       0.7894  2    1
# 15      15   33     0     6   0.2785       1.0000  2    1
# ...

# %%
Mileage_Result = pd.to_numeric(Mileage_Result)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-349182928ea2> in <module>
# ----> 1 Mileage_Result = pd.to_numeric(Mileage_Result)
#
# C:\ProgramData\Anaconda3\envs\YScraw\lib\site-packages\pandas\core\tools\numeric.py in to_numeric(arg, errors, downcast)
#     135         values = np.array([arg], dtype="O")
#     136     elif getattr(arg, "ndim", 1) > 1:
# --> 137         raise TypeError("arg must be a list, tuple, 1-d array, or Series")
#     138     else:
#     139         values = arg
#
# TypeError: arg must be a list, tuple, 1-d array, or Series

# %%
Mileage_Result = Mileage_Result.apply(pd.to_numeric)

# %%
Mileage_Result.dtypes
# Out:
# 순위                int64
# 마일리지              int64
# 전공자여부             int64
# 신청과목수             int64
# 총이수/졸업이수        float64
# 직전학기이수/학기당수강    float64
# 학년                int64
# 수강여부              int64
# dtype: object

# %%
Mileage_Result.drop('순위', axis=1, inplace = True)

# %%
converted = Mileage_Result.to_numpy()

# %%
converted
# Out:
# array([[36.    ,  0.    ,  6.    , ...,  0.8947,  3.    ,  1.    ],
#        [36.    ,  0.    ,  6.    , ...,  1.    ,  2.    ,  1.    ],
#        [36.    ,  0.    ,  6.    , ...,  0.921 ,  2.    ,  1.    ],
#        ...,
#        [ 1.    ,  0.    ,  5.    , ...,  0.6666,  2.    ,  0.    ],
#        [ 1.    ,  0.    ,  4.    , ...,  0.8157,  2.    ,  0.    ],
#        [ 1.    ,  0.    ,  3.    , ...,  0.4444,  2.    ,  0.    ]])

# %%
splited = np.split(converted, [-1,], axis = 1)

# %%
x, y = splited

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.7, random_state = 10)

# %%
y_train = y_train.reshape(-1, 1)
y_test = y_test.reshape(-1, 1)

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC

svm_clf = Pipeline([
    ('scaler', StandardScaler()),
    ('liear_svc', SVC(kernel='poly', degree=1, coef0=0.1, C=5, probability = True))
])
svm_clf.fit(x_train, y_train)
# Out:
# C:\ProgramData\Anaconda3\envs\YScraw\lib\site-packages\sklearn\utils\validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('liear_svc',
#                  SVC(C=5, coef0=0.1, degree=1, kernel='poly',
#                      probability=True))])

# %%
import matplotlib as plt

# %%
from sklearn.metrics import confusion_matrix
y_test_pred = svm_clf.predict(x_test)
cm = confusion_matrix(y_test, y_test_pred)

# %%
from sklearn.model_selection import cross_val_score
cross_val_score(svm_clf, x_train, y_train, cv=3, scoring='accuracy')
# Out:
# C:\ProgramData\Anaconda3\envs\YScraw\lib\site-packages\sklearn\utils\validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\ProgramData\Anaconda3\envs\YScraw\lib\site-packages\sklearn\utils\validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\ProgramData\Anaconda3\envs\YScraw\lib\site-packages\sklearn\utils\validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# array([0.98615917, 0.99305556, 0.97916667])

# %%
Mileage_Result.drop('총이수/졸업이수', axis=1, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-189-038411864391> in <module>
# ----> 1 Mileage_Result.drop('총이수/졸업이수', axis=1, inplace = True)
#
# C:\ProgramData\Anaconda3\envs\YScraw\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# C:\ProgramData\Anaconda3\envs\YScraw\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ...

# %%
Mileage_Result.drop('직전학기이수/학기당수강', axis=1, inplace = True)

# %%
Mileage_Result.drop('신청과목수', axis=1, inplace = True)

# %%
Mileage_Result
# Out:
#       마일리지  전공자여부  학년  수강여부
# 1       36      0   3     1
# 2       36      0   2     1
# 3       36      0   2     1
# 4       36      0   2     1
# 5       36      0   2     1
# 6       36      0   2     1
# 7       36      0   3     1
# 8       35      0   2     1
# 9       34      0   3     1
# 10      34      0   2     1
# 11      34      0   2     1
# 12      34      0   2     1
# 13      34      0   2     1
# 14      34      0   2     1
# 15      33      0   2     1
# 16      33      0   2     1
# 17      32      0   2     1
# 18      31      0   2     1
# 19      30      0   2     1
# 20      30      0   2     1
# 21      28      0   2     1
# 22      27      0   2     1
# 23      25      0   3     1
# 24      25      0   2     1
# 25      25      0   2     1
# 26      24      0   2     1
# 27      23      0   2     1
# 28      20      0   3     1
# 29      20      0   3     1
# 30      20      0   2     1
# 31      20      0   2     1
# 32      20      0   2     1
# ...

# %%
converted = Mileage_Result.to_numpy()
x, y = np.split(converted, [-1,], axis = 1)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 10)

# %%
svm_clf = Pipeline([
    ('scaler', StandardScaler()),
    ('liear_svc', SVC(kernel='poly', degree=1, coef0=0.1, C=5, probability = True))
])
svm_clf.fit(x_train, y_train)
# Out:
# C:\ProgramData\Anaconda3\envs\YScraw\lib\site-packages\sklearn\utils\validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('liear_svc',
#                  SVC(C=5, coef0=0.1, degree=1, kernel='poly',
#                      probability=True))])

# %%
y_test_pred = svm_clf.predict(x_test)
cm = confusion_matrix(y_test, y_test_pred)

# %%
print(cm)
# Out:
# [[249   0]
#  [  5 118]]

# %%
custom_test = []
for mileage in range(1, 37):
    for grade in range(2, 5):
        for major in range(0, 2):
                custom_test.append(np.array([mileage + 0. , major + 0., grade + 0.]))

# %%
custom_test = np.array(custom_test)
# custom_test.shape
custom_result = svm_clf.predict(custom_test)

# %%
for i, test in enumerate(custom_test):
    print("mileage : {} / major : {} / grade : {} /// result : {}".format(test[0], test[1], test[2], custom_result[i]))
# Out:
# mileage : 1.0 / major : 0.0 / grade : 2.0 /// result : 0
# mileage : 1.0 / major : 1.0 / grade : 2.0 /// result : 1
# mileage : 1.0 / major : 0.0 / grade : 3.0 /// result : 0
# mileage : 1.0 / major : 1.0 / grade : 3.0 /// result : 1
# mileage : 1.0 / major : 0.0 / grade : 4.0 /// result : 0
# mileage : 1.0 / major : 1.0 / grade : 4.0 /// result : 1
# mileage : 2.0 / major : 0.0 / grade : 2.0 /// result : 0
# mileage : 2.0 / major : 1.0 / grade : 2.0 /// result : 1
# mileage : 2.0 / major : 0.0 / grade : 3.0 /// result : 0
# mileage : 2.0 / major : 1.0 / grade : 3.0 /// result : 1
# mileage : 2.0 / major : 0.0 / grade : 4.0 /// result : 0
# mileage : 2.0 / major : 1.0 / grade : 4.0 /// result : 1
# mileage : 3.0 / major : 0.0 / grade : 2.0 /// result : 0
# mileage : 3.0 / major : 1.0 / grade : 2.0 /// result : 1
# mileage : 3.0 / major : 0.0 / grade : 3.0 /// result : 0
# mileage : 3.0 / major : 1.0 / grade : 3.0 /// result : 1
# ...

# %%
prob = svm_clf.predict_proba(custom_test)
for i, test in enumerate(custom_test):
    print("mileage : {} / major : {} / grade : {} /// result : {}, prob : {:.2f}".format(test[0], test[1], test[2], custom_result[i], prob[i][1]))
# Out:
# mileage : 1.0 / major : 0.0 / grade : 2.0 /// result : 0, prob : 0.00
# mileage : 1.0 / major : 1.0 / grade : 2.0 /// result : 1, prob : 0.98
# mileage : 1.0 / major : 0.0 / grade : 3.0 /// result : 0, prob : 0.00
# mileage : 1.0 / major : 1.0 / grade : 3.0 /// result : 1, prob : 1.00
# mileage : 1.0 / major : 0.0 / grade : 4.0 /// result : 0, prob : 0.00
# mileage : 1.0 / major : 1.0 / grade : 4.0 /// result : 1, prob : 1.00
# mileage : 2.0 / major : 0.0 / grade : 2.0 /// result : 0, prob : 0.00
# mileage : 2.0 / major : 1.0 / grade : 2.0 /// result : 1, prob : 1.00
# mileage : 2.0 / major : 0.0 / grade : 3.0 /// result : 0, prob : 0.00
# mileage : 2.0 / major : 1.0 / grade : 3.0 /// result : 1, prob : 1.00
# mileage : 2.0 / major : 0.0 / grade : 4.0 /// result : 0, prob : 0.00
# mileage : 2.0 / major : 1.0 / grade : 4.0 /// result : 1, prob : 1.00
# mileage : 3.0 / major : 0.0 / grade : 2.0 /// result : 0, prob : 0.00
# ...
